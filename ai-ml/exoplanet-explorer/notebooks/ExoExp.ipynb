# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
os.getcwd()
#from pathlib import Path
#base_path = Path.cwd()
#base_path
#file_path = base_path.parent / "data" / "exoplanets.csv"
#file_path
#import pandas as pd
#df = pd.read_csv(file_path, skiprows=96)
# Out:
# 'C:\\Projects\\GitHub\\mjbeall\\scientific-transition-portfolio\\ai-ml\\exoplanet-explorer\\notebooks'

# %%
df = pd.read_csv("../data/exoplanets.csv", skiprows=96)

# %%
df.head()
# Out:
#     pl_name hostname  default_flag  sy_snum  sy_pnum  discoverymethod  \
# 0  11 Com b   11 Com             1        2        1  Radial Velocity
# 1  11 Com b   11 Com             0        2        1  Radial Velocity
# 2  11 Com b   11 Com             0        2        1  Radial Velocity
# 3  11 UMi b   11 UMi             1        1        1  Radial Velocity
# 4  11 UMi b   11 UMi             0        1        1  Radial Velocity
#
#    disc_year                           disc_facility              soltype  \
# 0     2007.0                        Xinglong Station  Published Confirmed
# 1     2007.0                        Xinglong Station  Published Confirmed
# 2     2007.0                        Xinglong Station  Published Confirmed
# 3     2009.0  Thueringer Landessternwarte Tautenburg  Published Confirmed
# 4     2009.0  Thueringer Landessternwarte Tautenburg  Published Confirmed
#
#    pl_controv_flag  ... sy_vmagerr2  sy_kmag  sy_kmagerr1  sy_kmagerr2  \
# ...

# %%
df.shape
# Out:
# (39913, 92)

# %%
df.columns
# Out:
# Index(['pl_name', 'hostname', 'default_flag', 'sy_snum', 'sy_pnum',
#        'discoverymethod', 'disc_year', 'disc_facility', 'soltype',
#        'pl_controv_flag', 'pl_refname', 'pl_orbper', 'pl_orbpererr1',
#        'pl_orbpererr2', 'pl_orbperlim', 'pl_orbsmax', 'pl_orbsmaxerr1',
#        'pl_orbsmaxerr2', 'pl_orbsmaxlim', 'pl_rade', 'pl_radeerr1',
#        'pl_radeerr2', 'pl_radelim', 'pl_radj', 'pl_radjerr1', 'pl_radjerr2',
#        'pl_radjlim', 'pl_bmasse', 'pl_bmasseerr1', 'pl_bmasseerr2',
#        'pl_bmasselim', 'pl_bmassj', 'pl_bmassjerr1', 'pl_bmassjerr2',
#        'pl_bmassjlim', 'pl_bmassprov', 'pl_orbeccen', 'pl_orbeccenerr1',
#        'pl_orbeccenerr2', 'pl_orbeccenlim', 'pl_insol', 'pl_insolerr1',
#        'pl_insolerr2', 'pl_insollim', 'pl_eqt', 'pl_eqterr1', 'pl_eqterr2',
#        'pl_eqtlim', 'ttv_flag', 'st_refname', 'st_spectype', 'st_teff',
#        'st_tefferr1', 'st_tefferr2', 'st_tefflim', 'st_rad', 'st_raderr1',
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 39913 entries, 0 to 39912
# Data columns (total 92 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pl_name          39913 non-null  str
#  1   hostname         39913 non-null  str
#  2   default_flag     39913 non-null  int64
#  3   sy_snum          39913 non-null  int64
#  4   sy_pnum          39913 non-null  int64
#  5   discoverymethod  39913 non-null  str
#  6   disc_year        39911 non-null  float64
#  7   disc_facility    39913 non-null  str
#  8   soltype          39913 non-null  str
#  9   pl_controv_flag  39913 non-null  int64
#  10  pl_refname       39913 non-null  str
#  11  pl_orbper        36561 non-null  float64
#  12  pl_orbpererr1    34850 non-null  float64
#  13  pl_orbpererr2    34849 non-null  float64
#  14  pl_orbperlim     36561 non-null  float64
#  15  pl_orbsmax       22290 non-null  float64
#  16  pl_orbsmaxerr1   7812 non-null   float64
# ...

# %%
df["discoverymethod"].value_counts()
# Out:
# discoverymethod
# Transit                          35776
# Radial Velocity                   2922
# Microlensing                       798
# Imaging                            186
# Transit Timing Variations          162
# Eclipse Timing Variations           26
# Orbital Brightness Modulation       21
# Pulsar Timing                       13
# Astrometry                           6
# Pulsation Timing Variations          2
# Disk Kinematics                      1
# Name: count, dtype: int64

# %%
df["discoverymethod"].value_counts().head(10).plot(kind="bar")

plt.title("Exoplanet Discovery Methods")
plt.xlabel("Method")
plt.ylabel("Count")
plt.show()

# %%
df["disc_year"].value_counts().sort_index().plot()
plt.title("Exoplanet Discoveries Over Time")
plt.show()
